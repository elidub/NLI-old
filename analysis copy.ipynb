# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.insert(0, 'nli/')
from plot import PlotResults

# %%
plots = PlotResults(
    models = ['avg_word_emb', 'uni_lstm', 'bi_lstm', 'max_pool_lstm'],
    versions = ['version_0', 'version_0', 'version_0', 'version_0'],
    dims = [300, 2048, 4096, 4096],
)

# %%
premise     = 'We are living in a yellow submarine'
hypothesis  = 'I want to be, under the sea. In an octopus garden in the shade'

premise = 'Let us go to the beach'
hypothesis = 'We are going to the beach'

# Choose from ['avg_word_emb', 'uni_lstm', 'bi_lstm', 'max_pool_lstm']
model_type  = 'avg_word_emb'

plots.plot_new_sample(premise, hypothesis, model_type).show()
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]

# %%
plots.plot_examples().show()

# %%
plots.plot_violin().show()

# %%
plots.print_results()
# Out:
#               dim   dev  test  micro  macro
# Avg WordEmb   300  65.6  65.5   79.5   77.8
# Uni-LSTM     2048  81.2  80.9   77.4   76.8
# Bi-LSTM      4096  80.3  80.3   79.8   79.0
# BiLSTM-Max   4096  83.9  84.0   82.2   81.4
