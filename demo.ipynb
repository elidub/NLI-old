# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.insert(0, 'nli/')
from plot import PlotResults

# %%
plots = PlotResults(
    models = ['avg_word_emb', 'uni_lstm', 'bi_lstm', 'max_pool_lstm'],
    versions = ['version_0', 'version_0', 'version_0', 'version_0'],
    dims = [300, 2048, 4096, 4096],
)

# %%
premise     =  "I want to be, under the sea, in an octopus' garden in the shade"
hypothesis  =  "Come together, right now, over me!"

# Choose from ['avg_word_emb', 'uni_lstm', 'bi_lstm', 'max_pool_lstm']
model_type  = 'max_pool_lstm'

plots.plot_new_sample(premise, hypothesis, model_type)
# Out:
# Choosing baseline features!
# Choosing baseline features!
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]

# %%
plots.plot_examples()

# %%
plots.plot_bars()

# %%
plots.plot_violin()

# %%
plots.plot_embeddings()

# %%
plots.print_results()
# Out:
#               dim   dev  test  micro  macro
# Avg WordEmb   300  65.6  65.5   80.6   79.1
# Uni-LSTM     2048  81.2  80.9   78.0   77.6
# Bi-LSTM      4096  80.3  80.3   81.1   80.4
# BiLSTM-Max   4096  83.9  84.0   83.2   82.6
